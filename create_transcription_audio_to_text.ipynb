# %%
import openai
from dotenv import load_dotenv, find_dotenv
_ = load_dotenv(find_dotenv())
client = openai.Client()

# %%
audio = open('arquivos/audio/fala.mp3', 'rb')
transcricao = client.audio.transcriptions.create(
    model='gpt-4o-transcribe',
    file=audio,
)
print(transcricao.text)
# Out:
# TranscriptionTextDeltaEvent(delta='Python', type='transcript.text.delta', logprobs=None)
# TranscriptionTextDeltaEvent(delta=' é', type='transcript.text.delta', logprobs=None)
# TranscriptionTextDeltaEvent(delta=' uma', type='transcript.text.delta', logprobs=None)
# TranscriptionTextDeltaEvent(delta=' linguagem', type='transcript.text.delta', logprobs=None)
# TranscriptionTextDeltaEvent(delta=' de', type='transcript.text.delta', logprobs=None)
# TranscriptionTextDeltaEvent(delta=' programação', type='transcript.text.delta', logprobs=None)
# TranscriptionTextDeltaEvent(delta=' de', type='transcript.text.delta', logprobs=None)
# TranscriptionTextDeltaEvent(delta=' alto', type='transcript.text.delta', logprobs=None)
# TranscriptionTextDeltaEvent(delta=' nível', type='transcript.text.delta', logprobs=None)
# TranscriptionTextDeltaEvent(delta=',', type='transcript.text.delta', logprobs=None)
# TranscriptionTextDeltaEvent(delta=' interpret', type='transcript.text.delta', logprobs=None)
# TranscriptionTextDeltaEvent(delta='ada', type='transcript.text.delta', logprobs=None)
# TranscriptionTextDeltaEvent(delta=' de', type='transcript.text.delta', logprobs=None)
# TranscriptionTextDeltaEvent(delta=' script', type='transcript.text.delta', logprobs=None)
# TranscriptionTextDeltaEvent(delta=',', type='transcript.text.delta', logprobs=None)
# TranscriptionTextDeltaEvent(delta=' imper', type='transcript.text.delta', logprobs=None)
# TranscriptionTextDeltaEvent(delta='ativa', type='transcript.text.delta', logprobs=None)
# TranscriptionTextDeltaEvent(delta=',', type='transcript.text.delta', logprobs=None)
# TranscriptionTextDeltaEvent(delta=' orient', type='transcript.text.delta', logprobs=None)
# TranscriptionTextDeltaEvent(delta='ada', type='transcript.text.delta', logprobs=None)
# TranscriptionTextDeltaEvent(delta=' a', type='transcript.text.delta', logprobs=None)
# TranscriptionTextDeltaEvent(delta=' objetos', type='transcript.text.delta', logprobs=None)
# TranscriptionTextDeltaEvent(delta=',', type='transcript.text.delta', logprobs=None)
# TranscriptionTextDeltaEvent(delta=' funcional', type='transcript.text.delta', logprobs=None)
# TranscriptionTextDeltaEvent(delta=',', type='transcript.text.delta', logprobs=None)
# TranscriptionTextDeltaEvent(delta=' de', type='transcript.text.delta', logprobs=None)
# TranscriptionTextDeltaEvent(delta=' tip', type='transcript.text.delta', logprobs=None)
# TranscriptionTextDeltaEvent(delta='agem', type='transcript.text.delta', logprobs=None)
# TranscriptionTextDeltaEvent(delta=' dinâmica', type='transcript.text.delta', logprobs=None)
# TranscriptionTextDeltaEvent(delta=' e', type='transcript.text.delta', logprobs=None)
# TranscriptionTextDeltaEvent(delta=' forte', type='transcript.text.delta', logprobs=None)
# TranscriptionTextDeltaEvent(delta='.', type='transcript.text.delta', logprobs=None)
# TranscriptionTextDeltaEvent(delta=' Foi', type='transcript.text.delta', logprobs=None)
# TranscriptionTextDeltaEvent(delta=' lanç', type='transcript.text.delta', logprobs=None)
# TranscriptionTextDeltaEvent(delta='ada', type='transcript.text.delta', logprobs=None)
# TranscriptionTextDeltaEvent(delta=' por', type='transcript.text.delta', logprobs=None)
# TranscriptionTextDeltaEvent(delta=' Guido', type='transcript.text.delta', logprobs=None)
# TranscriptionTextDeltaEvent(delta=' van', type='transcript.text.delta', logprobs=None)
# TranscriptionTextDeltaEvent(delta=' Ross', type='transcript.text.delta', logprobs=None)
# TranscriptionTextDeltaEvent(delta='um', type='transcript.text.delta', logprobs=None)
# TranscriptionTextDeltaEvent(delta=' em', type='transcript.text.delta', logprobs=None)
# TranscriptionTextDeltaEvent(delta=' ', type='transcript.text.delta', logprobs=None)
# TranscriptionTextDeltaEvent(delta='199', type='transcript.text.delta', logprobs=None)
# TranscriptionTextDeltaEvent(delta='1', type='transcript.text.delta', logprobs=None)
# TranscriptionTextDeltaEvent(delta='.', type='transcript.text.delta', logprobs=None)
# TranscriptionTextDeltaEvent(delta=' Atualmente', type='transcript.text.delta', logprobs=None)
# TranscriptionTextDeltaEvent(delta=',', type='transcript.text.delta', logprobs=None)
# TranscriptionTextDeltaEvent(delta=' possui', type='transcript.text.delta', logprobs=None)
# TranscriptionTextDeltaEvent(delta=' um', type='transcript.text.delta', logprobs=None)
# TranscriptionTextDeltaEvent(delta=' modelo', type='transcript.text.delta', logprobs=None)
# TranscriptionTextDeltaEvent(delta=' de', type='transcript.text.delta', logprobs=None)
# TranscriptionTextDeltaEvent(delta=' desenvolvimento', type='transcript.text.delta', logprobs=None)
# TranscriptionTextDeltaEvent(delta=' comunit', type='transcript.text.delta', logprobs=None)
# TranscriptionTextDeltaEvent(delta='ário', type='transcript.text.delta', logprobs=None)
# TranscriptionTextDeltaEvent(delta=',', type='transcript.text.delta', logprobs=None)
# TranscriptionTextDeltaEvent(delta=' aberto', type='transcript.text.delta', logprobs=None)
# TranscriptionTextDeltaEvent(delta=' e', type='transcript.text.delta', logprobs=None)
# TranscriptionTextDeltaEvent(delta=' ger', type='transcript.text.delta', logprobs=None)
# TranscriptionTextDeltaEvent(delta='enciado', type='transcript.text.delta', logprobs=None)
# TranscriptionTextDeltaEvent(delta=' pela', type='transcript.text.delta', logprobs=None)
# TranscriptionTextDeltaEvent(delta=' organização', type='transcript.text.delta', logprobs=None)
# TranscriptionTextDeltaEvent(delta=' sem', type='transcript.text.delta', logprobs=None)
# TranscriptionTextDeltaEvent(delta=' fins', type='transcript.text.delta', logprobs=None)
# TranscriptionTextDeltaEvent(delta=' lucr', type='transcript.text.delta', logprobs=None)
# TranscriptionTextDeltaEvent(delta='ativos', type='transcript.text.delta', logprobs=None)
# TranscriptionTextDeltaEvent(delta=' Python', type='transcript.text.delta', logprobs=None)
# TranscriptionTextDeltaEvent(delta=' Software', type='transcript.text.delta', logprobs=None)
# TranscriptionTextDeltaEvent(delta=' Foundation', type='transcript.text.delta', logprobs=None)
# TranscriptionTextDeltaEvent(delta='.', type='transcript.text.delta', logprobs=None)
# TranscriptionTextDeltaEvent(delta=' Apesar', type='transcript.text.delta', logprobs=None)
# TranscriptionTextDeltaEvent(delta=' de', type='transcript.text.delta', logprobs=None)
# TranscriptionTextDeltaEvent(delta=' várias', type='transcript.text.delta', logprobs=None)
# TranscriptionTextDeltaEvent(delta=' partes', type='transcript.text.delta', logprobs=None)
# TranscriptionTextDeltaEvent(delta=' da', type='transcript.text.delta', logprobs=None)
# TranscriptionTextDeltaEvent(delta=' linguagem', type='transcript.text.delta', logprobs=None)
# TranscriptionTextDeltaEvent(delta=' poss', type='transcript.text.delta', logprobs=None)
# TranscriptionTextDeltaEvent(delta='uí', type='transcript.text.delta', logprobs=None)
# TranscriptionTextDeltaEvent(delta='rem', type='transcript.text.delta', logprobs=None)
# TranscriptionTextDeltaEvent(delta=' padrões', type='transcript.text.delta', logprobs=None)
# TranscriptionTextDeltaEvent(delta=' e', type='transcript.text.delta', logprobs=None)
# TranscriptionTextDeltaEvent(delta=' especific', type='transcript.text.delta', logprobs=None)
# TranscriptionTextDeltaEvent(delta='ações', type='transcript.text.delta', logprobs=None)
# TranscriptionTextDeltaEvent(delta=' forma', type='transcript.text.delta', logprobs=None)
# TranscriptionTextDeltaEvent(delta='is', type='transcript.text.delta', logprobs=None)
# TranscriptionTextDeltaEvent(delta=',', type='transcript.text.delta', logprobs=None)
# TranscriptionTextDeltaEvent(delta=' a', type='transcript.text.delta', logprobs=None)
# TranscriptionTextDeltaEvent(delta=' linguagem', type='transcript.text.delta', logprobs=None)
# TranscriptionTextDeltaEvent(delta=' como', type='transcript.text.delta', logprobs=None)
# TranscriptionTextDeltaEvent(delta=' um', type='transcript.text.delta', logprobs=None)
# TranscriptionTextDeltaEvent(delta=' todo', type='transcript.text.delta', logprobs=None)
# TranscriptionTextDeltaEvent(delta=' não', type='transcript.text.delta', logprobs=None)
# TranscriptionTextDeltaEvent(delta=' é', type='transcript.text.delta', logprobs=None)
# TranscriptionTextDeltaEvent(delta=' formal', type='transcript.text.delta', logprobs=None)
# TranscriptionTextDeltaEvent(delta='mente', type='transcript.text.delta', logprobs=None)
# TranscriptionTextDeltaEvent(delta=' especific', type='transcript.text.delta', logprobs=None)
# TranscriptionTextDeltaEvent(delta='ada', type='transcript.text.delta', logprobs=None)
# TranscriptionTextDeltaEvent(delta='.', type='transcript.text.delta', logprobs=None)
# TranscriptionTextDeltaEvent(delta=' O', type='transcript.text.delta', logprobs=None)
# TranscriptionTextDeltaEvent(delta=' padrão', type='transcript.text.delta', logprobs=None)
# TranscriptionTextDeltaEvent(delta=' na', type='transcript.text.delta', logprobs=None)
# TranscriptionTextDeltaEvent(delta=' prática', type='transcript.text.delta', logprobs=None)
# TranscriptionTextDeltaEvent(delta=' é', type='transcript.text.delta', logprobs=None)
# TranscriptionTextDeltaEvent(delta=' a', type='transcript.text.delta', logprobs=None)
# TranscriptionTextDeltaEvent(delta=' implementação', type='transcript.text.delta', logprobs=None)
# TranscriptionTextDeltaEvent(delta=' C', type='transcript.text.delta', logprobs=None)
# TranscriptionTextDeltaEvent(delta=' Python', type='transcript.text.delta', logprobs=None)
# TranscriptionTextDeltaEvent(delta='.', type='transcript.text.delta', logprobs=None)
# TranscriptionTextDeltaEvent(delta=' A', type='transcript.text.delta', logprobs=None)
# TranscriptionTextDeltaEvent(delta=' linguagem', type='transcript.text.delta', logprobs=None)
# TranscriptionTextDeltaEvent(delta=' foi', type='transcript.text.delta', logprobs=None)
# TranscriptionTextDeltaEvent(delta=' projet', type='transcript.text.delta', logprobs=None)
# TranscriptionTextDeltaEvent(delta='ada', type='transcript.text.delta', logprobs=None)
# TranscriptionTextDeltaEvent(delta=' com', type='transcript.text.delta', logprobs=None)
# TranscriptionTextDeltaEvent(delta=' a', type='transcript.text.delta', logprobs=None)
# TranscriptionTextDeltaEvent(delta=' filosofia', type='transcript.text.delta', logprobs=None)
# TranscriptionTextDeltaEvent(delta=' de', type='transcript.text.delta', logprobs=None)
# TranscriptionTextDeltaEvent(delta=' enfat', type='transcript.text.delta', logprobs=None)
# TranscriptionTextDeltaEvent(delta='izar', type='transcript.text.delta', logprobs=None)
# TranscriptionTextDeltaEvent(delta=' a', type='transcript.text.delta', logprobs=None)
# TranscriptionTextDeltaEvent(delta=' importância', type='transcript.text.delta', logprobs=None)
# TranscriptionTextDeltaEvent(delta=' do', type='transcript.text.delta', logprobs=None)
# TranscriptionTextDeltaEvent(delta=' esforço', type='transcript.text.delta', logprobs=None)
# TranscriptionTextDeltaEvent(delta=' do', type='transcript.text.delta', logprobs=None)
# TranscriptionTextDeltaEvent(delta=' program', type='transcript.text.delta', logprobs=None)
# TranscriptionTextDeltaEvent(delta='ador', type='transcript.text.delta', logprobs=None)
# TranscriptionTextDeltaEvent(delta=' sobre', type='transcript.text.delta', logprobs=None)
# TranscriptionTextDeltaEvent(delta=' o', type='transcript.text.delta', logprobs=None)
# TranscriptionTextDeltaEvent(delta=' esforço', type='transcript.text.delta', logprobs=None)
# TranscriptionTextDeltaEvent(delta=' comput', type='transcript.text.delta', logprobs=None)
# TranscriptionTextDeltaEvent(delta='acional', type='transcript.text.delta', logprobs=None)
# TranscriptionTextDeltaEvent(delta='.', type='transcript.text.delta', logprobs=None)
# TranscriptionTextDeltaEvent(delta=' Prior', type='transcript.text.delta', logprobs=None)
# TranscriptionTextDeltaEvent(delta='iza', type='transcript.text.delta', logprobs=None)
# TranscriptionTextDeltaEvent(delta=' a', type='transcript.text.delta', logprobs=None)
# TranscriptionTextDeltaEvent(delta=' leg', type='transcript.text.delta', logprobs=None)
# TranscriptionTextDeltaEvent(delta='ibilidade', type='transcript.text.delta', logprobs=None)
# TranscriptionTextDeltaEvent(delta=' do', type='transcript.text.delta', logprobs=None)
# TranscriptionTextDeltaEvent(delta=' código', type='transcript.text.delta', logprobs=None)
# TranscriptionTextDeltaEvent(delta=' sobre', type='transcript.text.delta', logprobs=None)
# TranscriptionTextDeltaEvent(delta=' a', type='transcript.text.delta', logprobs=None)
# TranscriptionTextDeltaEvent(delta=' velocidade', type='transcript.text.delta', logprobs=None)
# TranscriptionTextDeltaEvent(delta=' ou', type='transcript.text.delta', logprobs=None)
# TranscriptionTextDeltaEvent(delta=' express', type='transcript.text.delta', logprobs=None)
# TranscriptionTextDeltaEvent(delta='ividade', type='transcript.text.delta', logprobs=None)
# TranscriptionTextDeltaEvent(delta='.', type='transcript.text.delta', logprobs=None)
# TranscriptionTextDeltaEvent(delta=' Comb', type='transcript.text.delta', logprobs=None)
# TranscriptionTextDeltaEvent(delta='ina', type='transcript.text.delta', logprobs=None)
# TranscriptionTextDeltaEvent(delta=' uma', type='transcript.text.delta', logprobs=None)
# TranscriptionTextDeltaEvent(delta=' sint', type='transcript.text.delta', logprobs=None)
# TranscriptionTextDeltaEvent(delta='axe', type='transcript.text.delta', logprobs=None)
# TranscriptionTextDeltaEvent(delta=' conc', type='transcript.text.delta', logprobs=None)
# TranscriptionTextDeltaEvent(delta='isa', type='transcript.text.delta', logprobs=None)
# TranscriptionTextDeltaEvent(delta=' e', type='transcript.text.delta', logprobs=None)
# TranscriptionTextDeltaEvent(delta=' clara', type='transcript.text.delta', logprobs=None)
# TranscriptionTextDeltaEvent(delta=' com', type='transcript.text.delta', logprobs=None)
# TranscriptionTextDeltaEvent(delta=' os', type='transcript.text.delta', logprobs=None)
# TranscriptionTextDeltaEvent(delta=' recursos', type='transcript.text.delta', logprobs=None)
# TranscriptionTextDeltaEvent(delta=' poder', type='transcript.text.delta', logprobs=None)
# TranscriptionTextDeltaEvent(delta='osos', type='transcript.text.delta', logprobs=None)
# TranscriptionTextDeltaEvent(delta=' de', type='transcript.text.delta', logprobs=None)
# TranscriptionTextDeltaEvent(delta=' sua', type='transcript.text.delta', logprobs=None)
# TranscriptionTextDeltaEvent(delta=' biblioteca', type='transcript.text.delta', logprobs=None)
# TranscriptionTextDeltaEvent(delta=' padrão', type='transcript.text.delta', logprobs=None)
# TranscriptionTextDeltaEvent(delta=' e', type='transcript.text.delta', logprobs=None)
# TranscriptionTextDeltaEvent(delta=' por', type='transcript.text.delta', logprobs=None)
# TranscriptionTextDeltaEvent(delta=' módulos', type='transcript.text.delta', logprobs=None)
# TranscriptionTextDeltaEvent(delta=' e', type='transcript.text.delta', logprobs=None)
# TranscriptionTextDeltaEvent(delta=' frameworks', type='transcript.text.delta', logprobs=None)
# TranscriptionTextDeltaEvent(delta=' desenvol', type='transcript.text.delta', logprobs=None)
# TranscriptionTextDeltaEvent(delta='vidos', type='transcript.text.delta', logprobs=None)
# TranscriptionTextDeltaEvent(delta=' por', type='transcript.text.delta', logprobs=None)
# TranscriptionTextDeltaEvent(delta=' terceiros', type='transcript.text.delta', logprobs=None)
# TranscriptionTextDeltaEvent(delta='.', type='transcript.text.delta', logprobs=None)
# TranscriptionTextDoneEvent(text='Python é uma linguagem de programação de alto nível, interpretada de script, imperativa, orientada a objetos, funcional, de tipagem dinâmica e forte. Foi lançada por Guido van Rossum em 1991. Atualmente, possui um modelo de desenvolvimento comunitário, aberto e gerenciado pela organização sem fins lucrativos Python Software Foundation. Apesar de várias partes da linguagem possuírem padrões e especificações formais, a linguagem como um todo não é formalmente especificada. O padrão na prática é a implementação C Python. A linguagem foi projetada com a filosofia de enfatizar a importância do esforço do programador sobre o esforço computacional. Prioriza a legibilidade do código sobre a velocidade ou expressividade. Combina uma sintaxe concisa e clara com os recursos poderosos de sua biblioteca padrão e por módulos e frameworks desenvolvidos por terceiros.', type='transcript.text.done', logprobs=None)
